# %%
from qiskit import __version__
__version__
# Out:
# '1.3.1'

# %%
from qiskit import *

import matplotlib.pyplot as plt
# %matplotlib inline
 
qc = QuantumCircuit(2)

qc.draw('mpl')

# %%
qr = QuantumRegister(2)
qc = QuantumCircuit(qr)
qc.draw('mpl')

# %%
qr = QuantumRegister(2)
cr = ClassicalRegister(2)
qc = QuantumCircuit(qr, cr)
qc.draw('mpl')

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)

qc.draw('mpl')

# %%
from qiskit.quantum_info import Statevector

Statevector(qc)
# Out:
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))

# %%
from qiskit.visualization.array import array_to_latex

array_to_latex(Statevector(qc))
# Out:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
Statevector(qc).draw('hinton')

# %%
qc.measure_all()
qc.draw('mpl')

# %%
from qiskit.providers.fake_provider import GenericBackendV2

backend = GenericBackendV2(num_qubits=5)

job = backend.run(qc)

counts = job.result().get_counts()

counts
# Out:
# {'11': 485, '00': 520, '01': 12, '10': 7}

# %%
from qiskit.visualization import plot_histogram

plot_histogram(counts)

# %%
job = backend.run(qc, shots=5000)

counts = job.result().get_counts()

plot_histogram(counts)

# %%
transpiled_qc = transpile(qc, backend)
transpiled_qc.draw('mpl')

# %%
job = backend.run(transpiled_qc)

counts = job.result().get_counts()

plot_histogram(counts)

# %%
from qiskit_aer import AerSimulator
from qiskit_ibm_runtime.fake_provider import FakeJakartaV2

backend = FakeJakartaV2()

simulator = AerSimulator.from_backend(backend)

transpiled_qc = transpile(qc, backend)

job = simulator.run(transpiled_qc)

counts = job.result().get_counts()

plot_histogram(counts)

# %%
from qiskit_ibm_runtime.fake_provider import FakeJakartaV2 
from qiskit_ibm_runtime import SamplerV2 as Sampler


backend = FakeJakartaV2()

transpiled_qc = transpile(qc, backend)

sampler = Sampler(backend)
job = sampler.run([(transpiled_qc, [])], shots=1000)
result = job.result()

counts = result[0].data.meas.get_counts()
plot_histogram(counts)

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
token = "***********************************************"
service = QiskitRuntimeService(channel="ibm_quantum", token=token)

# %%
service.backends()
# Out:
# [<IBMBackend('ibm_brisbane')>,
#  <IBMBackend('ibm_brussels')>,
#  <IBMBackend('ibm_fez')>,
#  <IBMBackend('ibm_kyiv')>,
#  <IBMBackend('ibm_marrakesh')>,
#  <IBMBackend('ibm_sherbrooke')>,
#  <IBMBackend('ibm_strasbourg')>,
#  <IBMBackend('ibm_torino')>,
#  <IBMBackend('ibm_yonsei')>]

# %%
backend_real = service.backend("ibm_brisbane")

# %%
transpiled_qc_real = transpile(qc, backend_real)

# %%
transpiled_qc_real.draw('mpl', fold=True)

# %%
from qiskit_ibm_runtime import SamplerV2 as Sampler

sampler = Sampler(mode=backend_real)

job = sampler.run([(transpiled_qc_real, [])])

# %%
job.job_id()
# Out:
# 'cy6e1w79b62g008hny60'

# %%
job.result()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 job.result()
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\qiskit_ibm_runtime\runtime_job_v2.py:133, in RuntimeJobV2.result(self, timeout, decoder)
#     118 """Return the results of the job.
#     119
#     120 Args:
#    (...)
#     130     RuntimeInvalidStateError: If the job was cancelled, and attempting to retrieve result.
#     131 """
#     132 _decoder = decoder or self._final_result_decoder
# --> 133 self.wait_for_final_state(timeout=timeout)
#     134 if self._status == "ERROR":
#     135     error_message = self._reason if self._reason else self._error_message
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\qiskit_ibm_runtime\runtime_job_v2.py:253, in RuntimeJobV2.wait_for_final_state(self, timeout)
#     249             raise RuntimeJobTimeoutError(
#     250                 f"Timed out waiting for job to complete after {timeout} secs."
#     251             )
#     252         time.sleep(0.1)
# --> 253         status = self.status()
#     254 except futures.TimeoutError:
#     255     raise RuntimeJobTimeoutError(
#     256         f"Timed out waiting for job to complete after {timeout} secs."
#     257     )
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\qiskit_ibm_runtime\runtime_job_v2.py:170, in RuntimeJobV2.status(self)
#     164 def status(self) -> JobStatus:
#     165     """Return the status of the job.
#     166
#     167     Returns:
#     168         Status of this job.
#     169     """
# --> 170     self._set_status_and_error_message()
#     171     return self._status
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\qiskit_ibm_runtime\base_runtime_job.py:219, in BaseRuntimeJob._set_status_and_error_message(self)
#     217 """Fetch and set status and error message."""
#     218 if self._status not in self.JOB_FINAL_STATES:
# --> 219     response = self._api_client.job_get(job_id=self.job_id())
#     220     self._set_status(response)
#     221     self._set_error_message(response)
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\qiskit_ibm_runtime\api\clients\runtime.py:112, in RuntimeClient.job_get(self, job_id, exclude_params)
#     103 def job_get(self, job_id: str, exclude_params: bool = True) -> Dict:
#     104     """Get job data.
#     105
#     106     Args:
#    (...)
#     110         JSON response.
#     111     """
# --> 112     response = self._api.program_job(job_id).get(exclude_params=exclude_params)
#     113     logger.debug("Runtime job get response: %s", response)
#     114     return response
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\qiskit_ibm_runtime\api\rest\program_job.py:59, in ProgramJob.get(self, exclude_params)
#      57 if exclude_params:
#      58     payload["exclude_params"] = "true"
# ---> 59 return self.session.get(self.get_url("self"), params=payload).json(cls=RuntimeDecoder)
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\qiskit_ibm_runtime\api\session.py:328, in RetrySession.request(self, method, url, bare, **kwargs)
#     326 try:
#     327     self._log_request_info(final_url, method, kwargs)
# --> 328     response = super().request(method, final_url, headers=headers, **kwargs)
#     329     response.raise_for_status()
#     330 except RequestException as ex:
#     331     # Wrap the requests exceptions into a IBM Q custom one, for
#     332     # compatibility.
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\MOCTRAS\Documents\test\qi_venv\lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
backend_least_busy = service.least_busy()

# %%
transpiled_qc_real = transpile(qc, backend_least_busy)

transpiled_qc_real.draw('mpl')

# %%
sampler = Sampler(mode=backend_least_busy)

job = sampler.run([(transpiled_qc_real, [])])

job.job_id()
# Out:
# 'cy6ecga9b62g008hnzy0'

# %%
result = job.result()

# %%
counts = result[0].data.meas.get_counts()

plot_histogram(counts)
